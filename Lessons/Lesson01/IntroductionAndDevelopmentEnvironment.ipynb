# %% [markdown]
# ![](images/ckcslogo.png)
# # [Cool Kids Coding School](http://www.coolkidscodingschool.com)
# ## Course: _Programming Python with Graphics_
# ### Lesson 1: _Introduction and Development Environment_
# ---

# %% [markdown]
# **Overview**
# + Welcome!
# + What are we going to learn in this course, this semester?
# + How are we going to generate graphics?
# + Describe the development environment.
# + Familiarization with turtle.
#
# **What are we going to learn in this course, this semester?**
#
# This is a course about Python in the context of Graphics.  We are going to be reinforcing the concepts we learned in previous semesters, but instead of generating output that is primarily numerical or text based, the output our programs are going to generate this semester is going to be graphical.  We are going to draw every class.  Sounds like something students did in kindergarden, doesn't it?  In this class we are going to draw using Python.
#
# ![turtle1](images/turtle_graphic1.jpg)
#
# ![turtle2](images/turtle_graphic2.jpeg)
#
# **How are we going to generate graphics?**
#
# As we learned in previous semesters python is a programming language that supports thousands of packages.  There are packages that support random number functionality, there are packages that support audio processing.  As you can probable guess there are packages that support graphical output.  Specifically we are going to be using a package called **turtle**.  With the turtle package we will be able to use turtle statements in our python code to draw and manipulate graphical shapes.  In previous semesters, all our work was done in the Jupyter notebook, in this semester we will only go over the lesson in Jupyter.  All our work will be done in a platform called **Repl.it**.  A repl is a terminal that allows you to **R**ead-**E**valuate-**P**rint-**L**oop.  The reason we have to use a different platform is because turtle is not supported on the Jupyter notebook.
#
# **Describe the development environment**
#
# Every student has had an account created on [Repl.it](https://repl.it).  The password is the same as your jupyter hub account.  We will review the framework here later in this class.  Once you log in you will notice a classroom that is avaialble.  When you enter it you will see the in class and homework assignments.  The direct link to join the classroom is [here](https://repl.it/classroom/invite/erpuPhO).
#
# **Familiarization with turtle**
#
# Basic Turtle commands
#
# There are four basic turtle commands
#
# **Method 	Parameter 	Description**
#
# **forward()** 	amount 	Moves the turtle forward by the specified amount
#
# **backward()** 	amount 	Moves the turtle backward by the specified amount
#
# **right()** 	angle 	Turns the turtle clockwise
#
# **left()** 	angle 	Turns the turtle counter clockwise
#
# **penup()** 	None 	Picks up the turtle’s Pen
#
# **pendown()** 	None 	Puts down the turtle’s Pen
#
# **up()** 	None 	Picks up the turtle’s Pen
#
# **down()** 	None 	Puts down the turtle’s Pen
#
# **color()** 	Color name 	Changes the color of the turtle’s pen
#
# **fillcolor()** 	Color name 	Changes the color of the turtle will use to fill a polygon
#
# **heading()** 	None 	Returns the current heading
#
# **position()** 	None 	Returns the current position
#
# **goto()** 	x, y 	Move the turtle to position x,y
#
# **begin_fill()** 	None 	Remember the starting point for a filled polygon
#
# **end_fill()** 	None 	Close the polygon and fill with the current fill color
#
# **dot()** 	None 	Leave the dot at the current position
#
# **stamp()** 	None 	Leaves an impression of a turtle shape at the current location
#
# **shape()** 	shapename 	Should be ‘arrow’, ‘classic’, ‘turtle’ or ‘circle’
#
#
# The entire set of turtle commands can be viewed [here](https://docs.python.org/3.5/library/turtle.html).
#
# ## Any Questions?
# ---
# ###### for any questions contact <hw_help@coolkidscodingschool.com>
